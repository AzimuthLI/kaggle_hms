# %% [markdown]
# 1. Dummy submission score: 1.09
#
# 2. Reproduce EfficientNet:
# * https://www.kaggle.com/code/crackle/efficientnetb0-pytorch-starter-lb-0-40
#
# **Library**
#
# [Braindecode](https://braindecode.org/stable/index.html)
#
# **Discussion**:
#
# [Understanding Competition Data and EfficientNetB2 Starter - LB 0.43 🎉](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/468010)
#
# [Grad Cam - What is important in Spectrograms?](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/472976)
#
# [How To Create Spectrogram From Eeg? SOLVED? Boost CV and LB!](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/467877)
#
# [UPDATED - CatBoost Starter Notebook and Kaggle Dataset - LB 0.60](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/467576)
#
# [Understanding Competition Data and EfficientNetB2 Starter - LB 0.43 🎉](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/468010)
#
# [UPDATED - WaveNet Starter Notebook - LB 0.52 - Raw EEG Features Only!](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/468684)
#
# [Magic Formula to Convert EEG to Spectrograms!](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/469760)
#
# [1D ResNet Based Architecture Baseline - Achieve 0.4x LB with Raw Signals in 2 minutes](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/471666)
#
# [Understanding terminologies with examples](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/467000)
#
# [Resources for getting started with Brain Data - EEG](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/466768) (nice video)
#
# [Chris' EfficientNetB0 PyTorch Version](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/472092)
#
# (Notebook) [HMS-HBAC: ResNet34d Baseline [Training]](https://www.kaggle.com/code/ttahara/hms-hbac-resnet34d-baseline-training/#Training)
#
# ==================================================
#
# [G.O.A.T](https://www.kaggle.com/competitions/hms-harmful-brain-activity-classification/discussion/468277)
#
#
# **Transformers:**
#
# [Transformer based Spatial-Temporal Feature Learning for EEG Decoding](https://github.com/eeyhsong/EEG-Transformer?tab=readme-ov-file)
#
# [ViT based EEG transformer (UCSD Course Project)](https://github.com/zwcolin/EEG-Transformer)
#
# [ MIT Media Lab Course Project](https://github.com/redevaaa/Transformer-for-EEG)
#
# [EEGNet](https://github.com/vlawhern/arl-eegmodels)
#
# [Real-Time Seizure Detection using Electroencephalogram (EEG)](https://github.com/AITRICS/EEG_real_time_seizure_detection)
#
# [EEG dataset and toolbox](https://github.com/AlessioZanga/PyEEGLab)
